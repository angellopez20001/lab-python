# %% [markdown]
# ### Reduction operation: the sum of the numbers in the range [0, a)

# %%
import time
import sys
def reduc_operation(a):
    """Compute the sum of the numbers in the range [0, a)."""
    x = 0
    for i in range(a):
        x += i
    return x

# Secuencial

value = 1000000

initialTime = time.time()
suma = reduc_operation(value)
finalTime = time.time()

print("Time taken by reduction operation:", (finalTime - initialTime), "seconds")

# Utilizando las operaciones mágicas de ipython
# %timeit -r 2 reduc_operation(value)

print(f"\n \t Computing the sum of numbers in the range [0, value): {suma}\n")
# Out:
# Time taken by reduction operation: 0.035741567611694336 seconds
# 35 ms ± 391 μs per loop (mean ± std. dev. of 2 runs, 10 loops each)
#
#  	 Computing the sum of numbers in the range [0, value): 499999500000

# %% [markdown]
# ## Ejercicio 3.2 Apartado A

# %%
import time
import sys
def sumacomponentesdelista(a):
    """Compute the sum of the numbers in the range [0, a)."""
    x = 0
    for i in a:
        x += i
    return x

valor=int(sys.argv[1])   
listaasumar=list(range(valor))
##Primero usamos el bucle for
initialtime = time.time()
suma= sumacomponentesdelista(listaasumar)
finaltime=time.time()
tiempotot=finaltime-initialtime

print ("El numero total sumado es de "+str(suma))
print("El tiempo de ejecucion de la suma de la lista por bucle for es de:" +" " + str(tiempotot)+ " " + "segundos")
# %timeit -r 2 sumacomponentesdelista(listaasumar)
##Ahora probamos con la funcion sum
initialtime = time.time()
suma= sum(listaasumar)
finaltime=time.time()
tiempotot=finaltime-initialtime

print("El tiempo de ejecucion de la suma de la lista por funcion sum es de:" +" " + str(tiempotot)+ " " + "segundos")
# %timeit -r 2 sum(listaasumar)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 10
#       7         x += i
#       8     return x
# ---> 10 valor=int(sys.argv[1])
#      11 listaasumar=list(range(valor))
#      12 ##Primero usamos el bucle for
#
# ValueError: invalid literal for int() with base 10: '-f'

# %% [markdown]
# ## Ejercicio 3.2 Apartado B

# %%
import numpy as np #pongo el alias mas usado 

lista_np=np.array(listaasumar)

##Primero usamos el bucle for
initialtime = time.time()
suma= sumacomponentesdelista(lista_np)
finaltime=time.time()
tiempotot=finaltime-initialtime

print ("El numero total sumado es de "+str(suma))
print("El tiempo de ejecucion de la suma de la lista por bucle for es de:" +" " + str(tiempotot)+ " " + "segundos")
# %timeit -r 2 sumacomponentesdelista(lista_np)
##Ahora probamos con la funcion sum
initialtime = time.time()
suma= np.sum(lista_np)
finaltime=time.time()
tiempotot=finaltime-initialtime

print("El tiempo de ejecucion de la suma de la lista de numpy por funcion sum es de:" +" " + str(tiempotot)+ " " + "segundos")
# %timeit -r 2 sum(lista_np)
# Out:
# El numero total sumado es de 499999500000
# El tiempo de ejecucion de la suma de la lista por bucle for es de: 0.056702375411987305 segundos
# 53.2 ms ± 585 μs per loop (mean ± std. dev. of 2 runs, 10 loops each)
# El tiempo de ejecucion de la suma de la lista de numpy por funcion sum es de: 0.0004286766052246094 segundos
# 43.3 ms ± 301 μs per loop (mean ± std. dev. of 2 runs, 10 loops each)

# %% [markdown]
# ## Ejercicio 3.2 Apartado C
# Con los resultados obtenidos podemos comprobar que el codigo original donde hace una suma en un rango tarda unos 0.039 segundos; muy parecido a cuando hacemos un bucle for para la suma recorriendo tanto una lista o el array generado con numpy. Siendo el tiempo del bucle for en lista de 0.027 segundos y el del bucle for en el array de numpy de 0.057 segundos. Mientras tanto al usar la funcion sum de listas vemos que el tiempo se reduce a 0.006 segundos; pero podemos observar que la forma mas rapida es el uso de la funcion sum de numpy sobre el array obteniendo un tiempo de 0.0003.

# %% [markdown]
# ## Ejercicio 3.3 Apartado A

# %%
import numpy as np #pongo el alias mas usado 
import time
import numba
from numba import njit
lista_np=np.array(listaasumar)

@njit
def sumacomponentesdelista(a):
    """Compute the sum of the numbers in the range [0, a)."""
    x = 0
    for i in a:
        x += i
    return x
    
##Primero usamos el bucle for

initialtime = time.time()
suma= sumacomponentesdelista(lista_np)
finaltime=time.time()
tiempotot=finaltime-initialtime

print ("El numero total sumado es de "+str(suma))
print("El tiempo de ejecucion de la suma de la lista por bucle for es de:" +" " + str(tiempotot)+ " " + "segundos")
# %timeit -r 2 sumacomponentesdelista(lista_np)
##Ahora probamos con la funcion sum

@njit
def sumnp(a):
    b= np.sum(a)
    return b

initialtime = time.time()
suma= sumnp(lista_np)
finaltime=time.time()
tiempotot=finaltime-initialtime

print("El tiempo de ejecucion de la suma de la lista de numpy por funcion sum es de:" +" " + str(tiempotot)+ " " + "segundos")
# %timeit -r 2 sum(lista_np)
# Out:
# El numero total sumado es de 499999500000
# El tiempo de ejecucion de la suma de la lista por bucle for es de: 0.04805779457092285 segundos
# 406 μs ± 1.12 μs per loop (mean ± std. dev. of 2 runs, 1,000 loops each)
# El tiempo de ejecucion de la suma de la lista de numpy por funcion sum es de: 0.043946027755737305 segundos
# 41.9 ms ± 337 μs per loop (mean ± std. dev. of 2 runs, 10 loops each)

# %% [markdown]
# ## Ejercicio 3.3 Apartado B
#
# Como podemos observar con los resultados anteriores y los actuales usando el decorador @njit y podemos comprobar que para listas numpy si usamos el decorador el tiempo de ejecucion por la funcion de bucle for es acelerada a 0.04 pero a su vez si la aplicamos a la funcion del paquete numpy vemos que este en vez de ser acelerado decelera a 0.04segundos debido a que las funciones del paquete numpy estan ya optimizadas.
